# %% [markdown]
# # Hometask: Visualizing the Iris Dataset with Matplotlib
#
# This notebook will help you practice **all major types of Matplotlib pyplot plots** using the famous Iris dataset.
# You will use different plots to explore the relationships among features like *sepal length, sepal width, petal length, and petal width*.
#
# ---
# ### Tasks Covered:
# - Line Plot
# - Scatter Plot
# - Bar Chart
# - Histogram
# - Box Plot
# - Pie Chart
# - Area Plot
# - Subplots (combining multiple plots in one figure)
#
# 👉 **Instructions:** For each task, read the question, then fill in the missing code to create the required plot.

# %% [markdown]
# ## Step 1: Load the Iris Dataset
#
# We will use `sklearn.datasets.load_iris` to load the data into a Pandas DataFrame.

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()

df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

df['target'] = iris.target

df['species'] = df['target'].apply(lambda x: iris.target_names[x])

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %% [markdown]
# ## Task 1: Line Plot
#
# Plot a **line graph** of `sepal length (cm)` values for the first 50 samples.
# *Hint: Use `plt.plot`*

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()

sepal_length = iris.data[:50, 0]   

x = range(1, 51)

plt.plot(x, sepal_length, marker='o', linestyle='-', color='b')

plt.title("Sepal Length (cm) - İlk 50 nümunə")
plt.xlabel("Nümunə nömrəsi")
plt.ylabel("Sepal length (cm)")

plt.show()

# %% [markdown]
# ## Task 2: Scatter Plot
#
# Create a **scatter plot** of `sepal length (cm)` vs `sepal width (cm)` colored by species.
# *Hint: Use `plt.scatter`*

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

for i, target_name in enumerate(target_names):
    plt.scatter(
        X[y == i, 0],  
        X[y == i, 1],  
        label=target_name
    )

plt.title("Sepal Length vs Sepal Width (cm)")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()

plt.show()

# %% [markdown]
# ## Task 3: Bar Chart
#
# Create a **bar chart** of the average `petal length (cm)` for each species.
# *Hint: Use `plt.bar`*

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

avg_petal_length = []
for i in range(len(target_names)):
    avg_petal_length.append(X[y == i, 2].mean())  

plt.bar(target_names, avg_petal_length, color=['skyblue', 'orange', 'green'])


plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Average Petal Length (cm)")


plt.show()

# %% [markdown]
# ## Task 4: Histogram
#
# Plot a **histogram** of `petal width (cm)` values.
# *Hint: Use `plt.hist`*

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()
X = iris.data

petal_width = X[:, 3]

plt.hist(petal_width, bins=20, color="purple", edgecolor="black", alpha=0.7)

plt.title("Histogram of Petal Width (cm)")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequency")


plt.show()

# %% [markdown]
# ## Task 5: Box Plot
#
# Draw a **box plot** for all numeric features in the dataset.
# *Hint: Use `plt.boxplot` or `df.plot.box`*

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

plt.figure(figsize=(8,6))
df.plot.box()
plt.title("Box Plot of Iris Dataset Features")
plt.ylabel("cm")
plt.show()

# %% [markdown]
# ## Task 6: Pie Chart
#
# Create a **pie chart** showing the proportion of each species.
# *Hint: Use `plt.pie`*

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Dataset yüklənməsi
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = iris.target

# Species adlarını əlavə edirik (0,1,2 əvəzinə adlar yazılsın)
df["species_name"] = df["species"].map({0:"setosa", 1:"versicolor", 2:"virginica"})

# Hər növ üçün sayını hesablayırıq
species_counts = df["species_name"].value_counts()

# Pie chart
plt.figure(figsize=(6,6))
plt.pie(
    species_counts, 
    labels=species_counts.index, 
    autopct='%1.1f%%',     # Faiz göstəricisi
    startangle=90,         # Başlama bucağı
    colors=["skyblue", "lightgreen", "salmon"]
)
plt.title("Proportion of Iris Species")
plt.show()

# %% [markdown]
# ## Task 7: Area Plot
#
# Plot an **area plot** of the first 30 samples of sepal length and petal length.
# *Hint: Use `plt.fill_between`*

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Dataset yüklənməsi
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# İlk 30 nümunənin sepal length və petal length dəyərlərini götürək
x = range(30)  # nümunələrin indeksi
sepal_length = df['sepal length (cm)'][:30]
petal_length = df['petal length (cm)'][:30]

# Area plot (sahə qrafiki)
plt.figure(figsize=(10,6))
plt.fill_between(x, sepal_length, color="skyblue", alpha=0.5, label="Sepal Length")
plt.fill_between(x, petal_length, color="orange", alpha=0.5, label="Petal Length")

plt.title("Area Plot - First 30 Samples")
plt.xlabel("Sample Index")
plt.ylabel("Length (cm)")
plt.legend()
plt.show()

# %% [markdown]
# ## Task 8: Subplots
#
# Create **subplots** with 2 rows and 2 columns showing:
# 1. Line plot of sepal length (first 50 samples)
# 2. Scatter plot of sepal length vs sepal width
# 3. Histogram of petal width
# 4. Box plot of features
#
# *Hint: Use `plt.subplot`*

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# Dataseti yükləyirik və DataFrame şəklinə salırıq
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

plt.figure(figsize=(12, 10))  # Şəkilin ümumi ölçüsü

# 1. Line plot (ilk 50 nümunənin sepal length dəyərləri)
plt.subplot(2, 2, 1)
plt.plot(df['sepal length (cm)'][:50], marker="o")
plt.title("Line Plot - Sepal Length (first 50 samples)")
plt.xlabel("Sample Index")
plt.ylabel("Sepal Length (cm)")

# 2. Scatter plot (sepal length vs sepal width, növlərə görə rəngləndirilmiş)
plt.subplot(2, 2, 2)
for species, color in zip(df['species'].unique(), ["red", "green", "blue"]):
    subset = df[df['species'] == species]
    plt.scatter(subset['sepal length (cm)'], subset['sepal width (cm)'],
                label=species, alpha=0.7, color=color)
plt.title("Scatter Plot - Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()

# 3. Histogram (petal width)
plt.subplot(2, 2, 3)
plt.hist(df['petal width (cm)'], bins=20, color="purple", edgecolor="black")
plt.title("Histogram - Petal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequency")

# 4. Box plot (bütün feature-lər)
plt.subplot(2, 2, 4)
plt.boxplot(df.iloc[:, 0:4].values, labels=df.columns[0:4])
plt.title("Box Plot - Features")

# Layout düzəltmək
plt.tight_layout()
plt.show()
